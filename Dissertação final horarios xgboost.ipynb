# %% [markdown]
# ## Xgboost

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Time series jason brownlee.xlsx')
df.set_index('Timestamp',inplace=True)
df = df.rename(columns={'BAIRRO ALTO -  / FREQ B1': 'FREQUENCIA BOMBA 1', 'BAIRRO ALTO -  / FREQ B2': 'FREQUENCIA BOMBA 2','BAIRRO ALTO -  / FREQ B3':'FREQUENCIA BOMBA 3','BAIRRO ALTO - LT01 / NÍVEL':'NIVEL DO RESERVATÓRIO - LT01','BAIRRO ALTO - FT01 / ENT IRAI':'VAZÃO DE ENTRADA- FT01','BAIRRO ALTO - FT02 / GBAL':'VAZÃO DE GRAVIDADE - FT02','BAIRRO ALTO - FT03 / RBAL':'VAZÃO DE RECALQUE - FT03','BAIRRO ALTO - PT01 / SUCÇÃO':'PRESSÃO DE SUCÇÃO - PT01','BAIRRO ALTO - PT02 / RBAL':'PRESSÃO DE RECALQUE - PT02'})
df.replace(to_replace='Bad', value=np.nan, inplace=True)
df.interpolate(inplace=True)
df = df.resample('1H').mean().reset_index()

# %%
df.set_index('Timestamp',inplace=True)
df.head()
# Out:
#                      FREQUENCIA BOMBA 1  FREQUENCIA BOMBA 2  \
# Timestamp
# 2018-01-01 00:00:00           39.716118                 0.0
# 2018-01-01 01:00:00           40.692509                 0.0
# 2018-01-01 02:00:00           34.512108                 0.0
# 2018-01-01 03:00:00           33.531471                 0.0
# 2018-01-01 04:00:00           33.191261                 0.0
#
#                      FREQUENCIA BOMBA 3  NIVEL DO RESERVATÓRIO - LT01  \
# Timestamp
# 2018-01-01 00:00:00                 0.0                      4.027903
# 2018-01-01 01:00:00                 0.0                      4.241524
# 2018-01-01 02:00:00                 0.0                      4.352295
# 2018-01-01 03:00:00                 0.0                      4.136808
# 2018-01-01 04:00:00                 0.0                      3.947308
#
#                      VAZÃO DE ENTRADA- FT01  VAZÃO DE GRAVIDADE - FT02  \
# Timestamp
# 2018-01-01 00:00:00              270.285187                  76.920532
# 2018-01-01 01:00:00              268.635803                  83.023201
# 2018-01-01 02:00:00                0.000000                  82.351860
# 2018-01-01 03:00:00                0.000000                  69.360985
# 2018-01-01 04:00:00                0.000000                  59.742775
#
#                      VAZÃO DE RECALQUE - FT03  PRESSÃO DE SUCÇÃO - PT01  \
# Timestamp
# 2018-01-01 00:00:00                 61.992577                  5.232423
# 2018-01-01 01:00:00                 66.538521                  5.431031
# 2018-01-01 02:00:00                 57.269573                  5.555567
# 2018-01-01 03:00:00                 52.244926                  5.358496
# 2018-01-01 04:00:00                 49.718590                  5.184939
#
#                      PRESSÃO DE RECALQUE - PT02
# Timestamp
# 2018-01-01 00:00:00                   13.961227
# 2018-01-01 01:00:00                   13.961227
# 2018-01-01 02:00:00                   11.049756
# 2018-01-01 03:00:00                   11.115347
# 2018-01-01 04:00:00                   11.180938

# %%
# definindo 1 passo à frente
test_size = int(df.shape[0] * 0.3)
steps_ahead1 = 1
lags = 3

# %%
colunas = df.columns

for lag in range(1, lags):
    for column in colunas:
        df[column + '_t-' + str(lag)] = df[column].shift(lag)

# %%
df['y'] = df['NIVEL DO RESERVATÓRIO - LT01'].shift(-steps_ahead1)
# 2018-01-01 03:00:00                      83.023201
# 2018-01-01 04:00:00                      82.351860
# 2018-01-01 05:00:00                      69.360985
# 2018-01-01 06:00:00                      59.742775
#
#                      VAZÃO DE RECALQUE - FT03_t-2  \
# Timestamp
# 2018-01-01 02:00:00                     61.992577
# 2018-01-01 03:00:00                     66.538521
# 2018-01-01 04:00:00                     57.269573
# 2018-01-01 05:00:00                     52.244926
# 2018-01-01 06:00:00                     49.718590
#
#                      PRESSÃO DE SUCÇÃO - PT01_t-2  \
# Timestamp
# 2018-01-01 02:00:00                      5.232423
# 2018-01-01 03:00:00                      5.431031
# 2018-01-01 04:00:00                      5.555567
# 2018-01-01 05:00:00                      5.358496
# 2018-01-01 06:00:00                      5.184939
#
#                      PRESSÃO DE RECALQUE - PT02_t-2         y
# Timestamp
# 2018-01-01 02:00:00                       13.961227  4.136808
# 2018-01-01 03:00:00                       13.961227  3.947308
# 2018-01-01 04:00:00                       11.049756  3.832984
# 2018-01-01 05:00:00                       11.115347  4.128683
# 2018-01-01 06:00:00                       11.180938  4.389738
#
# [5 rows x 28 columns]

# %%
df_train = df.iloc[:-test_size, :]
df_test = df.iloc[-test_size:, :]

# %%
X_train = df_train.drop(['y'], axis=1)
y_train = df_train['y']
X_test = df_test.drop(['y'], axis=1)
y_test = df_test['y']

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
model = XGBRegressor(
    random_state=0,
    learning_rate=0.08,
    n_estimators=1300,
    max_depth=6,
    min_child_weight=14,
    subsample=0.75,
    colsample_bytree=0.5,
    objective='reg:squarederror',
    booster='gbtree'
    )

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=14,
#              missing=nan, monotone_constraints='()', n_estimators=1300,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
y_hat_train = model.predict(X_train)
y_hat_test = model.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.plot(y_train.values, label='y_train')
plt.plot(y_hat_train, label='y_hat_train')

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, mean_squared_error, r2_score

# %%
mse_train = mean_squared_error(y_train, y_hat_train)
mse_test = mean_squared_error(y_test, y_hat_test)
rmse_train=np.sqrt(mean_squared_error(y_train, y_hat_train))
rmse_test=np.sqrt(mean_squared_error(y_test, y_hat_test))
mae_train=mean_absolute_error(y_train, y_hat_train)
mae_test=mean_absolute_error(y_test, y_hat_test)
mape_train = int((np.mean(np.abs((y_train - y_hat_train) / y_train)) * 100))
mape_test = int((np.mean(np.abs((y_test - y_hat_test) / y_test)) * 100))
r2_train = r2_score(y_train, y_hat_train)
r2_test = r2_score(y_test, y_hat_test)

# %%
print('MSE train: %.3f, MSE test: %.3f' % (mse_train, mse_test))
print('MAPE train: %.3f, MAPE test: %.3f' % (mape_train, mape_test))
print('MAE train: %.3f, MAE test: %.3f' % (mae_train, mae_test))
print('RMSE train: %.3f, RMSE test: %.3f' % (rmse_train, rmse_test))
print('R2 train: %.3f, R2 test: %.3f' % (r2_train, r2_test))
# Out:
# MSE train: 0.001, MSE test: 0.020
# MAPE train: 0.000, MAPE test: 2.000
# MAE train: 0.017, MAE test: 0.083
# RMSE train: 0.027, RMSE test: 0.141
# R2 train: 0.998, R2 test: 0.954

# %%
## 12 passos à frente
test_size = int(df.shape[0] * 0.3)
steps_ahead7 = 12
lags = 3

# %%
colunas7 = df.columns

for lag in range(1, lags):
    for column in colunas7:
        df[column + '_t-' + str(lag)] = df[column].shift(lag)

# %%
df['y'] = df['NIVEL DO RESERVATÓRIO - LT01'].shift(-steps_ahead7)
df.dropna(axis=0, inplace=True)
df.head()
# Out:
#                      FREQUENCIA BOMBA 1  FREQUENCIA BOMBA 2  \
# Timestamp
# 2018-01-01 06:00:00           34.174210                 0.0
# 2018-01-01 07:00:00           35.942287                 0.0
# 2018-01-01 08:00:00           43.891830                 0.0
# 2018-01-01 09:00:00           48.734074                 0.0
# 2018-01-01 10:00:00           51.120010                 0.0
#
#                      FREQUENCIA BOMBA 3  NIVEL DO RESERVATÓRIO - LT01  \
# Timestamp
# 2018-01-01 06:00:00                 0.0                      4.128683
# 2018-01-01 07:00:00                 0.0                      4.389738
# 2018-01-01 08:00:00                 0.0                      4.198495
# 2018-01-01 09:00:00                 0.0                      4.013699
# 2018-01-01 10:00:00                 0.0                      4.207844
#
#                      VAZÃO DE ENTRADA- FT01  VAZÃO DE GRAVIDADE - FT02  \
# Timestamp
# 2018-01-01 06:00:00              284.199951                  55.226677
# 2018-01-01 07:00:00                0.000000                  55.884785
# 2018-01-01 08:00:00                0.000000                  59.514992
# 2018-01-01 09:00:00              291.549774                  75.489296
# 2018-01-01 10:00:00              291.679474                 102.019135
#
#                      VAZÃO DE RECALQUE - FT03  PRESSÃO DE SUCÇÃO - PT01  \
# Timestamp
# 2018-01-01 06:00:00                 48.235146                  5.375868
# 2018-01-01 07:00:00                 51.996529                  5.577349
# 2018-01-01 08:00:00                 64.828224                  5.354414
# 2018-01-01 09:00:00                 77.221199                  5.183626
# 2018-01-01 10:00:00                 88.984375                  5.299061
#
#                      PRESSÃO DE RECALQUE - PT02  FREQUENCIA BOMBA 1_t-1  ...  \
# Timestamp                                                                ...
# 2018-01-01 06:00:00                   12.206452               34.850670  ...
# 2018-01-01 07:00:00                   12.991898               34.174210  ...
# 2018-01-01 08:00:00                   16.956018               35.942287  ...
# 2018-01-01 09:00:00                   19.082754               43.891830  ...
# 2018-01-01 10:00:00                   18.931648               48.734074  ...
#
#                      FREQUENCIA BOMBA 1_t-2_t-2  FREQUENCIA BOMBA 2_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                   34.512108                         0.0
# 2018-01-01 07:00:00                   33.531471                         0.0
# 2018-01-01 08:00:00                   33.191261                         0.0
# 2018-01-01 09:00:00                   34.850670                         0.0
# 2018-01-01 10:00:00                   34.174210                         0.0
#
#                      FREQUENCIA BOMBA 3_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                         0.0
# 2018-01-01 07:00:00                         0.0
# 2018-01-01 08:00:00                         0.0
# 2018-01-01 09:00:00                         0.0
# 2018-01-01 10:00:00                         0.0
#
#                      NIVEL DO RESERVATÓRIO - LT01_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                              4.352295
# 2018-01-01 07:00:00                              4.136808
# 2018-01-01 08:00:00                              3.947308
# 2018-01-01 09:00:00                              3.832984
# 2018-01-01 10:00:00                              4.128683
#
#                      VAZÃO DE ENTRADA- FT01_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                        0.000000
# 2018-01-01 07:00:00                        0.000000
# 2018-01-01 08:00:00                        0.000000
# 2018-01-01 09:00:00                      283.889404
# 2018-01-01 10:00:00                      284.199951
#
#                      VAZÃO DE GRAVIDADE - FT02_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                          82.351860
# 2018-01-01 07:00:00                          69.360985
# 2018-01-01 08:00:00                          59.742775
# 2018-01-01 09:00:00                          54.762260
# 2018-01-01 10:00:00                          55.226677
#
#                      VAZÃO DE RECALQUE - FT03_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                         57.269573
# 2018-01-01 07:00:00                         52.244926
# 2018-01-01 08:00:00                         49.718590
# 2018-01-01 09:00:00                         49.945602
# 2018-01-01 10:00:00                         48.235146
#
#                      PRESSÃO DE SUCÇÃO - PT01_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                          5.555567
# 2018-01-01 07:00:00                          5.358496
# 2018-01-01 08:00:00                          5.184939
# 2018-01-01 09:00:00                          5.073123
# 2018-01-01 10:00:00                          5.375868
#
#                      PRESSÃO DE RECALQUE - PT02_t-2_t-2     y_t-2
# Timestamp
# 2018-01-01 06:00:00                           11.049756  3.832984
# 2018-01-01 07:00:00                           11.115347  4.128683
# 2018-01-01 08:00:00                           11.180938  4.389738
# 2018-01-01 09:00:00                           12.047937  4.198495
# 2018-01-01 10:00:00                           12.206452  4.013699
#
# [5 rows x 66 columns]

# %%
df_train7 = df.iloc[:-test_size, :]
df_test7 = df.iloc[-test_size:, :]

# %%
X_train7 = df_train7.drop(['y'], axis=1)
y_train7 = df_train7['y']
X_test7 = df_test7.drop(['y'], axis=1)
y_test7 = df_test7['y']

# %%
model7 = XGBRegressor(
    random_state=0,
    learning_rate=0.08,
    n_estimators=1300,
    max_depth=6,
    min_child_weight=14,
    subsample=0.75,
    colsample_bytree=0.5,
    objective='reg:squarederror',
    booster='gbtree'
    )

# %%
model7.fit(X_train7, y_train7)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=14,
#              missing=nan, monotone_constraints='()', n_estimators=1300,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
y_hat_train7 = model7.predict(X_train7)
y_hat_test7 = model7.predict(X_test7)

# %%
import matplotlib.pyplot as plt
plt.plot(y_train7.values, label='y_train')
plt.plot(y_hat_train7, label='y_hat_train')

# %%
mse_train7 = mean_squared_error(y_train7, y_hat_train7)
mse_test7 = mean_squared_error(y_test7, y_hat_test7)
rmse_train7=np.sqrt(mean_squared_error(y_train7, y_hat_train7))
rmse_test7=np.sqrt(mean_squared_error(y_test7, y_hat_test7))
mae_train7=mean_absolute_error(y_train7, y_hat_train7)
mae_test7=mean_absolute_error(y_test7, y_hat_test7)
mape_train7 = int((np.mean(np.abs((y_train7 - y_hat_train7) / y_train7)) * 100))
mape_test7 = int((np.mean(np.abs((y_test7 - y_hat_test7) / y_test7)) * 100))
r2_train7 = r2_score(y_train7, y_hat_train7)
r2_test7 = r2_score(y_test7, y_hat_test7)

# %%
print('MSE train: %.3f, MSE test: %.3f' % (mse_train7, mse_test7))
print('MAPE train: %.3f, MAPE test: %.3f' % (mape_train7, mape_test7))
print('MAE train: %.3f, MAE test: %.3f' % (mae_train7, mae_test7))
print('RMSE train: %.3f, RMSE test: %.3f' % (rmse_train7, rmse_test7))
print('R2 train: %.3f, R2 test: %.3f' % (r2_train7, r2_test7))
# Out:
# MSE train: 0.016, MSE test: 0.745
# MAPE train: 2.000, MAPE test: 18.000
# MAE train: 0.091, MAE test: 0.657
# RMSE train: 0.126, RMSE test: 0.863
# R2 train: 0.965, R2 test: -0.714

# %%
# 24 passos à frente
test_size = int(df.shape[0] * 0.3)
steps_ahead14 = 24
lags = 3

# %%
colunas14 = df.columns

for lag in range(1, lags):
    for column in colunas14:
        df[column + '_t-' + str(lag)] = df[column].shift(lag)

# %%
df['y'] = df['NIVEL DO RESERVATÓRIO - LT01'].shift(-steps_ahead14)
df.dropna(axis=0, inplace=True)
df.head()
# Out:
#                      FREQUENCIA BOMBA 1  FREQUENCIA BOMBA 2  \
# Timestamp
# 2018-01-01 12:00:00           51.996922            0.000000
# 2018-01-01 13:00:00           57.988792           21.987036
# 2018-01-01 14:00:00           58.435562            0.000000
# 2018-01-01 15:00:00           57.271839            0.000000
# 2018-01-01 16:00:00           46.214523            0.000000
#
#                      FREQUENCIA BOMBA 3  NIVEL DO RESERVATÓRIO - LT01  \
# Timestamp
# 2018-01-01 12:00:00                 0.0                      4.378140
# 2018-01-01 13:00:00                 0.0                      3.997223
# 2018-01-01 14:00:00                 0.0                      4.070675
# 2018-01-01 15:00:00                 0.0                      4.166386
# 2018-01-01 16:00:00                 0.0                      4.265089
#
#                      VAZÃO DE ENTRADA- FT01  VAZÃO DE GRAVIDADE - FT02  \
# Timestamp
# 2018-01-01 12:00:00                0.000000                 147.215225
# 2018-01-01 13:00:00              288.392853                 131.411713
# 2018-01-01 14:00:00              283.143951                 123.302452
# 2018-01-01 15:00:00              274.760162                 118.042953
# 2018-01-01 16:00:00              275.261566                 119.989746
#
#                      VAZÃO DE RECALQUE - FT03  PRESSÃO DE SUCÇÃO - PT01  \
# Timestamp
# 2018-01-01 12:00:00                 99.479164                  5.293007
# 2018-01-01 13:00:00                108.912041                  4.862528
# 2018-01-01 14:00:00                106.298676                  5.070752
# 2018-01-01 15:00:00                102.010719                  5.193643
# 2018-01-01 16:00:00                 81.174637                  5.363875
#
#                      PRESSÃO DE RECALQUE - PT02  FREQUENCIA BOMBA 1_t-1  ...  \
# Timestamp                                                                ...
# 2018-01-01 12:00:00                   16.970486               50.419205  ...
# 2018-01-01 13:00:00                   20.949074               51.996922  ...
# 2018-01-01 14:00:00                   21.987303               57.988792  ...
# 2018-01-01 15:00:00                   22.004305               58.435562  ...
# 2018-01-01 16:00:00                   15.986690               57.271839  ...
#
#                      FREQUENCIA BOMBA 1_t-2_t-2_t-2  \
# Timestamp
# 2018-01-01 12:00:00                       34.174210
# 2018-01-01 13:00:00                       35.942287
# 2018-01-01 14:00:00                       43.891830
# 2018-01-01 15:00:00                       48.734074
# 2018-01-01 16:00:00                       51.120010
#
#                      FREQUENCIA BOMBA 2_t-2_t-2_t-2  \
# Timestamp
# 2018-01-01 12:00:00                             0.0
# 2018-01-01 13:00:00                             0.0
# 2018-01-01 14:00:00                             0.0
# 2018-01-01 15:00:00                             0.0
# 2018-01-01 16:00:00                             0.0
#
#                      FREQUENCIA BOMBA 3_t-2_t-2_t-2  \
# Timestamp
# 2018-01-01 12:00:00                             0.0
# 2018-01-01 13:00:00                             0.0
# 2018-01-01 14:00:00                             0.0
# 2018-01-01 15:00:00                             0.0
# 2018-01-01 16:00:00                             0.0
#
#                      NIVEL DO RESERVATÓRIO - LT01_t-2_t-2_t-2  \
# Timestamp
# 2018-01-01 12:00:00                                  4.128683
# 2018-01-01 13:00:00                                  4.389738
# 2018-01-01 14:00:00                                  4.198495
# 2018-01-01 15:00:00                                  4.013699
# 2018-01-01 16:00:00                                  4.207844
#
#                      VAZÃO DE ENTRADA- FT01_t-2_t-2_t-2  \
# Timestamp
# 2018-01-01 12:00:00                          284.199951
# 2018-01-01 13:00:00                            0.000000
# 2018-01-01 14:00:00                            0.000000
# 2018-01-01 15:00:00                          291.549774
# 2018-01-01 16:00:00                          291.679474
#
#                      VAZÃO DE GRAVIDADE - FT02_t-2_t-2_t-2  \
# Timestamp
# 2018-01-01 12:00:00                              55.226677
# 2018-01-01 13:00:00                              55.884785
# 2018-01-01 14:00:00                              59.514992
# 2018-01-01 15:00:00                              75.489296
# 2018-01-01 16:00:00                             102.019135
#
#                      VAZÃO DE RECALQUE - FT03_t-2_t-2_t-2  \
# Timestamp
# 2018-01-01 12:00:00                             48.235146
# 2018-01-01 13:00:00                             51.996529
# 2018-01-01 14:00:00                             64.828224
# 2018-01-01 15:00:00                             77.221199
# 2018-01-01 16:00:00                             88.984375
#
#                      PRESSÃO DE SUCÇÃO - PT01_t-2_t-2_t-2  \
# Timestamp
# 2018-01-01 12:00:00                              5.375868
# 2018-01-01 13:00:00                              5.577349
# 2018-01-01 14:00:00                              5.354414
# 2018-01-01 15:00:00                              5.183626
# 2018-01-01 16:00:00                              5.299061
#
#                      PRESSÃO DE RECALQUE - PT02_t-2_t-2_t-2  y_t-2_t-2
# Timestamp
# 2018-01-01 12:00:00                               12.206452   3.917960
# 2018-01-01 13:00:00                               12.991898   4.035455
# 2018-01-01 14:00:00                               16.956018   4.060713
# 2018-01-01 15:00:00                               19.082754   3.742448
# 2018-01-01 16:00:00                               18.931648   3.682262
#
# [5 rows x 142 columns]

# %%
df_train14 = df.iloc[:-test_size, :]
df_test14 = df.iloc[-test_size:, :]

# %%
X_train14 = df_train14.drop(['y'], axis=1)
y_train14 = df_train14['y']
X_test14 = df_test14.drop(['y'], axis=1)
y_test14 = df_test14['y']

# %%
model14 = XGBRegressor(
    random_state=0,
    learning_rate=0.08,
    n_estimators=1300,
    max_depth=6,
    min_child_weight=14,
    subsample=0.75,
    colsample_bytree=0.5,
    objective='reg:squarederror',
    booster='gbtree'
    )

# %%
model14.fit(X_train14, y_train14)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=14,
#              missing=nan, monotone_constraints='()', n_estimators=1300,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
y_hat_train14 = model14.predict(X_train14)
y_hat_test14 = model14.predict(X_test14)

# %%
import matplotlib.pyplot as plt
plt.plot(y_train14.values, label='y_train')
plt.plot(y_hat_train14, label='y_hat_train')

# %%
mse_train14 = mean_squared_error(y_train14, y_hat_train14)
mse_test14 = mean_squared_error(y_test14, y_hat_test14)
rmse_train14=np.sqrt(mean_squared_error(y_train14, y_hat_train14))
rmse_test14=np.sqrt(mean_squared_error(y_test14, y_hat_test14))
mae_train14=mean_absolute_error(y_train14, y_hat_train14)
mae_test14=mean_absolute_error(y_test14, y_hat_test14)
mape_train14 = int((np.mean(np.abs((y_train14 - y_hat_train14) / y_train14)) * 100))
mape_test14 = int((np.mean(np.abs((y_test14 - y_hat_test14) / y_test14)) * 100))
r2_train14 = r2_score(y_train14, y_hat_train14)
r2_test14 = r2_score(y_test14, y_hat_test14)

# %%
print('MSE train: %.3f, MSE test: %.3f' % (mse_train14, mse_test14))
print('MAPE train: %.3f, MAPE test: %.3f' % (mape_train14, mape_test14))
print('MAE train: %.3f, MAE test: %.3f' % (mae_train14, mae_test14))
print('RMSE train: %.3f, RMSE test: %.3f' % (rmse_train14, rmse_test14))
print('R2 train: %.3f, R2 test: %.3f' % (r2_train14, r2_test14))
# Out:
# MSE train: 0.011, MSE test: 0.419
# MAPE train: 2.000, MAPE test: 15.000
# MAE train: 0.075, MAE test: 0.490
# RMSE train: 0.103, RMSE test: 0.648
# R2 train: 0.976, R2 test: 0.038

# %%
## 48 passos à frente
test_size = int(df.shape[0] * 0.3)
steps_ahead30 = 48
lags = 3

# %%
colunas30 = df.columns

for lag in range(1, lags):
    for column in colunas30:
        df[column + '_t-' + str(lag)] = df[column].shift(lag)

# %%
df['y'] = df['NIVEL DO RESERVATÓRIO - LT01'].shift(-steps_ahead30)
df.dropna(axis=0, inplace=True)
df.head()
# Out:
#                      FREQUENCIA BOMBA 1  FREQUENCIA BOMBA 2  \
# Timestamp
# 2018-01-01 20:00:00           51.284271                 0.0
# 2018-01-01 21:00:00           50.209923                 0.0
# 2018-01-01 22:00:00           49.518959                 0.0
# 2018-01-01 23:00:00           43.746536                 0.0
# 2018-01-02 00:00:00           41.581829                 0.0
#
#                      FREQUENCIA BOMBA 3  NIVEL DO RESERVATÓRIO - LT01  \
# Timestamp
# 2018-01-01 20:00:00                 0.0                      3.917960
# 2018-01-01 21:00:00                 0.0                      4.035455
# 2018-01-01 22:00:00                 0.0                      4.060713
# 2018-01-01 23:00:00                 0.0                      3.742448
# 2018-01-02 00:00:00                 0.0                      3.682262
#
#                      VAZÃO DE ENTRADA- FT01  VAZÃO DE GRAVIDADE - FT02  \
# Timestamp
# 2018-01-01 20:00:00              279.348541                 109.422928
# 2018-01-01 23:00:00                                102.010719
# 2018-01-02 00:00:00                                 81.174637
#
#                      PRESSÃO DE SUCÇÃO - PT01_t-2_t-2_t-2_t-2  \
# Timestamp
# 2018-01-01 20:00:00                                  5.293007
# 2018-01-01 21:00:00                                  4.862528
# 2018-01-01 22:00:00                                  5.070752
# 2018-01-01 23:00:00                                  5.193643
# 2018-01-02 00:00:00                                  5.363875
#
#                      PRESSÃO DE RECALQUE - PT02_t-2_t-2_t-2_t-2  y_t-2_t-2_t-2
# Timestamp
# 2018-01-01 20:00:00                                   16.970486       4.235716
# 2018-01-01 21:00:00                                   20.949074       4.242189
# 2018-01-01 22:00:00                                   21.987303       4.264114
# 2018-01-01 23:00:00                                   22.004305       4.007146
# 2018-01-02 00:00:00                                   15.986690       4.082773
#
# [5 rows x 294 columns]

# %%
df_train30 = df.iloc[:-test_size, :]
df_test30 = df.iloc[-test_size:, :]

# %%
X_train30 = df_train30.drop(['y'], axis=1)
y_train30 = df_train30['y']
X_test30 = df_test30.drop(['y'], axis=1)
y_test30 = df_test30['y']

# %%
model30 = XGBRegressor(
    random_state=0,
    learning_rate=0.08,
    n_estimators=1300,
    max_depth=6,
    min_child_weight=14,
    subsample=0.75,
    colsample_bytree=0.5,
    objective='reg:squarederror',
    booster='gbtree'
    )

# %%
model30.fit(X_train30, y_train30)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.08, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=14,
#              missing=nan, monotone_constraints='()', n_estimators=1300,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
y_hat_train30 = model30.predict(X_train30)
y_hat_test30 = model30.predict(X_test30)

# %%
import matplotlib.pyplot as plt
plt.plot(y_train30.values, label='y_train')
plt.plot(y_hat_train30, label='y_hat_train')

# %%
mse_train30 = mean_squared_error(y_train30, y_hat_train30)
mse_test30 = mean_squared_error(y_test30, y_hat_test30)
rmse_train30=np.sqrt(mean_squared_error(y_train30, y_hat_train30))
rmse_test30=np.sqrt(mean_squared_error(y_test30, y_hat_test30))
mae_train30=mean_absolute_error(y_train30, y_hat_train30)
mae_test30=mean_absolute_error(y_test30, y_hat_test30)
mape_train30 = int((np.mean(np.abs((y_train30 - y_hat_train30) / y_train30)) * 100))
mape_test30 = int((np.mean(np.abs((y_test30- y_hat_test30) / y_test30)) * 100))
r2_train30 = r2_score(y_train30, y_hat_train30)
r2_test30 = r2_score(y_test30, y_hat_test30)

# %%
print('MSE train: %.3f, MSE test: %.3f' % (mse_train30, mse_test30))
print('MAPE train: %.3f, MAPE test: %.3f' % (mape_train30, mape_test30))
print('MAE train: %.3f, MAE test: %.3f' % (mae_train30, mae_test30))
print('RMSE train: %.3f, RMSE test: %.3f' % (rmse_train30, rmse_test30))
print('R2 train: %.3f, R2 test: %.3f' % (r2_train30, r2_test30))
# Out:
# MSE train: 0.010, MSE test: 0.522
# MAPE train: 2.000, MAPE test: 17.000
# MAE train: 0.073, MAE test: 0.563
# RMSE train: 0.101, RMSE test: 0.723
# R2 train: 0.977, R2 test: -0.195

# %%
df_train.head()
# Out:
#                      FREQUENCIA BOMBA 1  FREQUENCIA BOMBA 2  \
#                      VAZÃO DE RECALQUE - FT03_t-2  \
# Timestamp
# 2018-01-01 02:00:00                           NaN
# 2018-01-01 03:00:00                           NaN
# 2018-01-01 04:00:00                     57.269573
# 2018-01-01 05:00:00                     52.244926
# 2018-01-01 06:00:00                     49.718590
#
#                      PRESSÃO DE SUCÇÃO - PT01_t-2  \
# Timestamp
# 2018-01-01 02:00:00                           NaN
# 2018-01-01 03:00:00                           NaN
# 2018-01-01 04:00:00                      5.555567
# 2018-01-01 05:00:00                      5.358496
# 2018-01-01 06:00:00                      5.184939
#
#                      PRESSÃO DE RECALQUE - PT02_t-2         y
# Timestamp
# 2018-01-01 02:00:00                             NaN  4.070675
# 2018-01-01 03:00:00                             NaN  4.166386
# 2018-01-01 04:00:00                       11.049756  4.265089
# 2018-01-01 05:00:00                       11.115347  4.076128
# 2018-01-01 06:00:00                       11.180938  3.746744
#
# [5 rows x 28 columns]

# %%
df_train7.head()
# Out:
#                      FREQUENCIA BOMBA 1  FREQUENCIA BOMBA 2  \
# Timestamp
# 2018-01-01 06:00:00           34.174210                 0.0
# 2018-01-01 07:00:00           35.942287                 0.0
# 2018-01-01 08:00:00           43.891830                 0.0
# 2018-01-01 09:00:00           48.734074                 0.0
# 2018-01-01 10:00:00           51.120010                 0.0
#
#                      FREQUENCIA BOMBA 3  NIVEL DO RESERVATÓRIO - LT01  \
# Timestamp
# 2018-01-01 06:00:00                 0.0                      4.128683
# 2018-01-01 07:00:00                 0.0                      4.389738
# 2018-01-01 08:00:00                 0.0                      4.198495
# 2018-01-01 09:00:00                 0.0                      4.013699
# 2018-01-01 10:00:00                 0.0                      4.207844
#
#                      VAZÃO DE ENTRADA- FT01  VAZÃO DE GRAVIDADE - FT02  \
# Timestamp
# 2018-01-01 06:00:00              284.199951                  55.226677
# 2018-01-01 07:00:00                0.000000                  55.884785
# 2018-01-01 08:00:00                0.000000                  59.514992
# 2018-01-01 09:00:00              291.549774                  75.489296
# 2018-01-01 10:00:00              291.679474                 102.019135
#
#                      VAZÃO DE RECALQUE - FT03  PRESSÃO DE SUCÇÃO - PT01  \
# Timestamp
# 2018-01-01 06:00:00                 48.235146                  5.375868
# 2018-01-01 07:00:00                 51.996529                  5.577349
# 2018-01-01 08:00:00                 64.828224                  5.354414
# 2018-01-01 09:00:00                 77.221199                  5.183626
# 2018-01-01 10:00:00                 88.984375                  5.299061
#
#                      PRESSÃO DE RECALQUE - PT02  FREQUENCIA BOMBA 1_t-1  ...  \
# Timestamp                                                                ...
# 2018-01-01 06:00:00                   12.206452                     NaN  ...
# 2018-01-01 07:00:00                   12.991898               34.174210  ...
# 2018-01-01 08:00:00                   16.956018               35.942287  ...
# 2018-01-01 09:00:00                   19.082754               43.891830  ...
# 2018-01-01 10:00:00                   18.931648               48.734074  ...
#
#                      FREQUENCIA BOMBA 1_t-2_t-2  FREQUENCIA BOMBA 2_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                         NaN                         NaN
# 2018-01-01 07:00:00                         NaN                         NaN
# 2018-01-01 08:00:00                         NaN                         NaN
# 2018-01-01 09:00:00                         NaN                         NaN
# 2018-01-01 10:00:00                    34.17421                         0.0
#
#                      FREQUENCIA BOMBA 3_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                         NaN
# 2018-01-01 07:00:00                         NaN
# 2018-01-01 08:00:00                         NaN
# 2018-01-01 09:00:00                         NaN
# 2018-01-01 10:00:00                         0.0
#
#                      NIVEL DO RESERVATÓRIO - LT01_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                                   NaN
# 2018-01-01 07:00:00                                   NaN
# 2018-01-01 08:00:00                                   NaN
# 2018-01-01 09:00:00                                   NaN
# 2018-01-01 10:00:00                              4.128683
#
#                      VAZÃO DE ENTRADA- FT01_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                             NaN
# 2018-01-01 07:00:00                             NaN
# 2018-01-01 08:00:00                             NaN
# 2018-01-01 09:00:00                             NaN
# 2018-01-01 10:00:00                      284.199951
#
#                      VAZÃO DE GRAVIDADE - FT02_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                                NaN
# 2018-01-01 07:00:00                                NaN
# 2018-01-01 08:00:00                                NaN
# 2018-01-01 09:00:00                                NaN
# 2018-01-01 10:00:00                          55.226677
#
#                      VAZÃO DE RECALQUE - FT03_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                               NaN
# 2018-01-01 07:00:00                               NaN
# 2018-01-01 08:00:00                               NaN
# 2018-01-01 09:00:00                               NaN
# 2018-01-01 10:00:00                         48.235146
#
#                      PRESSÃO DE SUCÇÃO - PT01_t-2_t-2  \
# Timestamp
# 2018-01-01 06:00:00                               NaN
# 2018-01-01 07:00:00                               NaN
# 2018-01-01 08:00:00                               NaN
# 2018-01-01 09:00:00                               NaN
# 2018-01-01 10:00:00                          5.375868
#
#                      PRESSÃO DE RECALQUE - PT02_t-2_t-2     y_t-2
# Timestamp
# 2018-01-01 06:00:00                                 NaN       NaN
# 2018-01-01 07:00:00                                 NaN       NaN
# 2018-01-01 08:00:00                                 NaN  3.746744
# 2018-01-01 09:00:00                                 NaN  3.797072
# 2018-01-01 10:00:00                           12.206452  3.917960
#
# [5 rows x 66 columns]

# %%
## Gráfico comparando o horizonte de previsão no X-gboost

plt.figure(figsize=(10,6))
plt.plot(y_train.values, label='y_train', color='blue')
plt.plot(y_hat_train, label='y_hat_train',color='black')
plt.plot(y_hat_train7, label='y_hat_train', color='green')
plt.plot(y_hat_train14, label='y_hat_train',color='red')
plt.plot(y_hat_train30, label='y_hat_train',color='grey')
plt.legend(['Série original','1 passo à frente','7 passos à frente','14 passos à frente','30 passos à frente'])

# %%
## Gráfico comparando o horizonte de previsão no X-gboost

plt.figure(figsize=(10,6))
plt.plot(y_test.values, label='y_train', color='blue')
plt.plot(y_hat_test, label='y_hat_train',color='black')
plt.plot(y_hat_test7, label='y_hat_train', color='green')
plt.plot(y_hat_test14, label='y_hat_train',color='red')
plt.plot(y_hat_test30, label='y_hat_train',color='grey')
plt.legend(['Série original','1 passo à frente','7 passos à frente','14 passos à frente','30 passos à frente'])
